# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # LOAD AND PERFORM BASIC CHECKS FOR DATASET

# %%
# Data Source: XML exports of past Maintenance Action Form (MAF)
# records extracted from the Decision Knowledge
# Programming for Logistics Analysis and Technical
# Evaluation (DECKPLATE) system, the NAVAIR data
# warehouse for aircraft maintenance, flight, and usage
# data.


# Load test, validation and train datasets
val_x = pd.read_csv("./Data/development-x.csv")
val_y = pd.read_csv("./Data/development-y.csv")
# Create a training dataset
train_x = pd.read_csv("./Data/training-x.csv")
train_y = pd.read_csv("./Data/training-y.csv")
# Create a testing dataset
test_x = pd.read_csv("./Data/test-x.csv")
test_y = pd.read_csv("./Data/test-y.csv")

# %%
# Rename first column
train_x.rename(columns={'Unnamed: 0':'Code'},inplace=True)
train_y.rename(columns={'Unnamed: 0':'Code'},inplace=True)
test_x.rename(columns={'Unnamed: 0':'Code'},inplace=True)
test_y.rename(columns={'Unnamed: 0':'Code'},inplace=True)
val_x.rename(columns={'Unnamed: 0':'Code'},inplace=True)
val_y.rename(columns={'Unnamed: 0':'Code'},inplace=True)

# %%
train_x.head()
# Out:
#    Code                                        DISCREPANCY
# 0  2266  rh nose landing gear tire has multiple cuts ex...
# 1  8993                                mrh accumulator low
# 2  5059  hole in yellow tail rotor boot. mrc-300 card 1...
# 3  4936  ib hydraulic hose for lh mlg brake pressure ha...
# 4  3846                   mrh fluid level is low

# %%
train_x.shape,train_y.shape
# Out:
# ((22407, 2), (22407, 2))

# %%
train = train_x.merge(train_y,how='inner',on='Code')
test  = test_x.merge(test_y,how='inner',on='Code')
val   = val_x.merge(val_y,how='inner',on='Code')

# %%
print(val[val['Code']==1644]['DISCREPANCY'][0])
print(val[val['Code']==1644]['DISCREPANCY'][1])
print("**************************************************")
print(val[val['Code']==1644]['CORRECTIVE ACTION'][0])
print(val[val['Code']==1644]['CORRECTIVE ACTION'][1])
print("**************************************************")
# Out:
# mrh hyd level in the red.
# mrh hyd level in the red.
# **************************************************
# serviced mrh accum to 1675 psi, high green, oat: 22*c iaw gai-000. current a/c hours: 1,316.200. inspected all dampers for leak. checks good area fod free and secure.
# removed and replaced lh nlg tire iaw sss 3240. ataf apaf aff.
# **************************************************

# %%
train_x[train_x['Code']==5059]
# Out:
#        Code                                        DISCREPANCY
# 2      5059  hole in yellow tail rotor boot. mrc-300 card 1...
# 11832  5059                    rh nose landing gear tire worn.

# %%
train_y[train_y['Code']==5059]
# Out:
#        Code                                  CORRECTIVE ACTION
# 2      5059  applied rtv to hole in yellow tail rotor boot ...
# 11832  5059  replaced rh nlg tire iaw sss 3240. used pema 6...

# %%
train_y['CORRECTIVE ACTION'].isnull().sum()
# Out:
# 545

# %%
# print("Discrepancies corresponding to 'Unnamed: 0' 5059 are: ")
# print(train_x[train_x['Code']==5059]['DISCREPANCY'][2])
# print(train_x[train_x['Code']==5059]['DISCREPANCY'][11832])
# print("**************************************************")
# print("Corrective Actions corresponding to 'Unnamed: 0' 5059 are: ")
# print(train_y[train_y['Code']==5059]['CORRECTIVE ACTION'][2])
# print(train_y[train_y['Code']==5059]['CORRECTIVE ACTION'][11832])
# print("**************************************************")

# %%
train.shape[0]
# Out:
# 27105

# %%
train[train['DISCREPANCY']=='red upper pcr bolt is worn out of limits.']
# Out:
#     Code                                DISCREPANCY  \
# 45  5002  red upper pcr bolt is worn out of limits.
# 46  5002  red upper pcr bolt is worn out of limits.
#
#                                     CORRECTIVE ACTION
# 45                                                NaN
# 46  replaced worn pcr bolt iaw: a1-h60ra-150-300. ...

# %%
print("For Corr Action Text: ")
print("Repeated Corr Act percentages train is: ", 100*(1-len(set(train['CORRECTIVE ACTION'].tolist()))/train.shape[0]))
print("Repeated Corr Act percentages test is: ", 100*(1-len(set(test['CORRECTIVE ACTION'].tolist()))/test.shape[0]))
print("Repeated Corr Act percentages val is: ", 100*(1-len(set(val['CORRECTIVE ACTION'].tolist()))/val.shape[0]))
# Out:
# For Corr Action Text:
# Repeated Corr Act percentages train is:  21.674967718133185
# Repeated Corr Act percentages test is:  5.662580268534734
# Repeated Corr Act percentages val is:  9.60742505957607

# %%
train["D_CA"] = train['DISCREPANCY']+"__"+train['CORRECTIVE ACTION']
test["D_CA"]  = test['DISCREPANCY']+"__" +test['CORRECTIVE ACTION']
val["D_CA"]   = val['DISCREPANCY']+"__"+val['CORRECTIVE ACTION']

# %% [markdown]
# # PROMPT CREATION EXISTING

# %%
import csv, random

f_x = csv.reader(open("Data/training-x.csv"))
f_y = csv.reader(open("Data/training-y.csv"))

train_x = {}
train_y = {}

for idx, row in enumerate(f_x):
    train_x[idx] = row[1]

for idx, row in enumerate(f_y):
    train_y[idx] = row[1]

print(len(train_x), len(train_y))

pairs = []
for idx in train_x:
    if train_x[idx] != '' and train_y[idx] != '':
        pairs.append((train_x[idx], train_y[idx]))
# Out:
# 22408 22408

# %%
pairs
# Out:
# [('DISCREPANCY', 'CORRECTIVE ACTION'),
#  ('rh nose landing gear tire has multiple cuts exceeding the 4/32 cut limit          ',
#   'removed and replaced rh nlg tire iaw sss 3240 pema 9964 ataf apaf aff.  '),
#  ('mrh accumulator low',
#   'serviced mrh accumulator to second green iaw gai-000 nitrogen pressor 1600 psi oat 29c. flight hours 3530.1 needs conditional. area clean secure and fod free. pema s/n 6cksa67650'),
#  ('hole in yellow tail rotor boot. mrc-300 card 11.12',
#   'applied rtv to hole in yellow tail rotor boot iaw srm-000. all checks good. area fod free and secure.'),
#  ('mrh fluid level is low          ',
#   'servicing not required iaw: gai-000. area clean and fod free. pema used: 6fksa75955  '),
#  ('main rotor head low          ',
#   'serviced mrh accumulator iaw: a1-h60ra-gai-000. hydraulics gauge high green and nitrogen gauge 1450 psi using hsu 229 and n2 bottle 017 at 22 degrees cel. aircraft flight hours 1227.9. all checks good area fod free and secure.  '),
#  ('mrh hydraulic fluid low. at white line in between green and red.          ',
#   'serviced mrh accumulator in accordance with a1-h60ra-gai-000. hyd- 2nd green, nitrogen- 1550. oat 28c. a/c hours 1848.7. area cleaned secure, and fod free. pema s/n 8556.  '),
#  ('upper scissor bolt shims worn mrc-400 card 23.5          ',
#   'removed and replaced upper scissor bolt shims iaw 150-300. area fod free and secure.  '),
#  ('scir change:  1gtenqw.  no spread light          ',
#   'removed and replaced the tail rotor indexer iaw 150-300. opcheck good iaw 150-200. area secure and fod free.  '),
#  ('right hand nose landing gear tire pressure low.',
#   'rh nlg tire serviced iaw sss 1210 ataf apaf aff pema 67332'),
#  ('lh nlg tire worn beyond limits          ',
#   'replaced lh nlg tire iaw sss 3240 ataf apaf aff used pema 67331  '),
#  ('mrh accumulator hydraulic gauge bad.          ',
#   'removed and replaced mrh accumulator gauge iaw a1-h60ra-150-300. area secure and fod free.  '),
#  ('verify tail rotor mag pick up gap.          ',
#   'adjusted tail rotor magnetic pickup gap iaw 150-300. gap measures 0.015, limit is 0.015 to 0.025. checks good. area secure and fod free.  '),
#  ('missing tail abrasion strip red paddle. refer t jcn:q20280201 for fod search.          ',
#   'installed tail rotor abrasion strip iaw ref: srm-000. checks good. area secure and fod free at time of inspection.  '),
#  ('lh outboard mlg tire flat and out of limits.',
#   'removed and replaced l/h o/b mlg tire iaw sss 3224. ataf,apaf,aff. pema 11 was used.'),
#  ("lh nlg tire assy worn beyond limitations, cut in the sidewall measures 1/4''.          ",
#   'replaced lh nlg tire assy iaw sss 3240 ataf apaf aff  '),
#  ('bifilar between black and yellow spindle (closest to black spindle) has a bifilar bushing cracked.          ',
#   'removed and replaced bifilar absorber iaw 150-300.  reference mcn 00cdq8e and 00cdsr7 for inprocess inspections, parts ordered, and removed and installed blocks.  area secure and no fod found at time of inspection.  pema s/n 6cksa67509  '),
#  ('tail rotor bias out of limits.          ',
#   'made adjustments to the tail rotor for bias being ool iaw a1-h60ra-140-300. adjustments were made to the black and yellow paddle black started at 2.7 and yellow started at 2.8. adjusted both to 3.0. area is secure and fod free. pema 48884  '),
#  ('main rotor damper outboard bleed plug is stripped. (black)          ',
#   'removed and replaced black main rotor damper iaw-15-300. area secure and fod check complete. refer to jcn:qg0023128 for 9-13 damper tq checks.  '),
#  ('loose tail paddle boot red          ',
#   'tightened red tail rotor paddle boot iaw: a1-h60ra-150-300. ietms used: 48100. ietms used: 48100. area secure and fod free.  '),
#  ('mrh accumulator fluid low',
#   'serviced main rotor head accumulator iaw gai-000. navy class: 3 // pods sn: 00168 // hsu sn: 281// nan4b: pzn461 // hydraulics: hi green // nitrogen: 1550 // oats: 29Â¿c // time last serviced: 2383.7 time now: 2393.2. refer to jcn: q71212575 for conditonal'),
#  ('broken torque stripe on yellow mrh spindle cam follower nut          ',
#   'tq checked yellow mrh spindle cam follower nut and applied tq stripe. tq checks good iaw 150-300. area secure and fod free at time of inspection.  '),
#  ('teflon liner on red spindle droop stop ring is worn out causing metal to metal contact between droop stop ring and support.          ',
#   'removed and replaced red spindle iaw a1-h60ra-150-300.  area fod free and secure.  '),
#  ('severe galvanic corrosion on 2 rivets of red trb tip cap.',
#   'refer to jcn: q64260571 for removal and replacement on #1 tail rotor paddle.'),
#  ('scir change:  1v4zvw7.  minor surface corrosion on red blade fold motor nut; needs sealant.',
#   'cleaned, treated, and prserved with cpc type 2, and sealant iaw na 01-1a-509. area secured. fod free.'),
#  ('scir change:  16pmnef.  ccdd: 25nov19 yellow blade lockpin puller dogbone worn sealant',
#   'removed corrosion, cleaned treated and preserved with cpc type 2 yellow lockpin puller dogbone h/w iaw 01-1a-509 and srm-000. refer to jcn: pq4330282 for new sealant maf. area is secure and fod free.'),
#  ('main rotor head accumulator low.          ',
#   'serviced mrh accumulator iaw gai-000. hyd fluid reads high green and nitrogen pressure side reads 1350psi. oat 22* celcius. a/c hours is 1375.8. navy class 0.  '),
#  ('main rotor head low          ',
#   'serviced mrh accumulator iaw: gai-000. serviced to high green, 1450psi, oat 17c, current ac time 2337.9. area secure fod free. no conditional required.  '),
#  ('remove and reinstall all blades. reinstall when notified by maint control.          ',
#   'removed and reinstall all mrh blades iaw i50-300. area fod free and secure.  '),
#  ('l wow switch 1 f(p) when aircraft would go weight off wheels. posted 5 times.          ',
#   'replaced l/h wow switch 1 iaw ietm sss:3221 ataf.apaf.aff.  '),
#  ('main rotor head accumulator low.',
#   'serviced main rotor head accumulator in accordance with a1-h60ra-gai-000. hydraulic fluid level in yellow, nitrogen at 1650psi. a/c hours: 1157.5. area secure and fod free. pema s/n: 8878.'),
#  ('red pitch horn adel clamp bracket h/w corroded',
#   'removed corrosion from red pitch horn adel clamp bracket hardware. cleaned and treated in accordance with 01-1a-509. area is clean, secure and fod free. pema s/n: 7iksa26143.'),
#  ('black bim indicator stays black upon testing          ',
#   'serviced black bim to 12psi iaw: a1-h60ra-gai-000. area secured and fod free at time of inspection.  '),
#  ('both nlg, lh ob and rh ib mlg tire pressure low.',
#   'serviced tires iaw sss 1210. used pema 67332. ataf apaf aff'),
#  ('main rotor head final grounds ool.          ',
#   'removed 14 oz on blue spindle and added 52 oz on red spindle iaw:a1-h60rs-vib-200. all checks good. area secured and fod free at time of inspection. all vibs within limits.  '),
#  ('scir change:  16pmnee.  ccdd:25nov19 blue blade lockpin puller dogbone worn sealant',
#   'removed corrosion, cleaned treated and preserved with cpc type 2 blue lockpin puller  dogbone h/w iaw 01-1a-509 and srm-000. refer to jcn: pq4330281 for new sealant maf. area is secure and fod free.'),
#  ('fwd scissors assy has up and down play.',
#   'performed axial play inspection for fwd scissor spherical bearing iaw reference: 150-300 wp 017. exceptable limits : .033    measured value: .015. scissor assy within limits, area secure and fod free.'),
#  ('remove tail rotor paddles iaw applicable mims for inboard retention plate torque check.  r/w/d/b/m/c.          ',
#   'removed and re-installed tail rotor paddles iaw 150-300. all checks good area secure and fod free.  '),
#  ('red damper elbow misaligned. (no leakage/no evidence of broken torque)          ',
#   'realigned damper elbow to be parallel with damper centerline iaw 150-300. sealant not applied. refer to mcn:00jdt3j for sealant application. area fod free and secure.  '),
#  ('tail rotor vibrations out of limits          ',
#   'added 16 grams on quadrant 1 and 74 grams on quadrant 2 iaw:a1-h60rs-vib-200. area secure and fod free.  '),
#  ('delamination/bond separation in critical tip block area affecting structural integrity of blue mrb.          ',
#   'refer to jcn: qg0008a03 / mcn: 00jcdqw and jcn: qg0019442/ mcn: 00jcdqz for completion.  '),
#  ('red damper inboard spherical bearing worn more than 0.010 limit.',
#   'removed and replaced red damper inboard spherical bearing iaw a1-h60ra-150-300. area is secure and fod free at time of inspection.'),
#  ('scir change:  2366o97.  scir change:  2366nui.  left brakes are weak and grind when actuated.          ',
#   'replaced lh ob brakes iaw sss 3240. used pema 67347. ataf apaf aff.  '),
#  ('scir change:  1v4zvw5.  minor surface corrosion on blue spindle anti-flap bolt; needs sealant.',
#   'removed corrosion, cleaned, treated, and preserved blue anti-flap h/w with ams3265 iaw: 01-1a-509 and a1-h60ra-150-300. area secure and fod free. cure check good.'),
#  ('black tail rotor blade tip cap cracked.',
#   'removed and replaced black tail rotor tip cap iaw 150-400.  area secure and fod free.  pema s/n: 8fkka48489.  refer to mcn: 00cgi4m for paint.'),
#  ('red outbrd pcl failed 9-13 tq check          ',
#   'removed cotter key, torqued outbord pcl to 200inlb iaw:150-300. area secure and fod free. refer to jcn: q70156325 for new 9-13.  '),
#  ('trb red boot has a hole marked location on boot card 11.13 daily          ',
#   'inspected red tail rotor boot iaw 150-300. tear within limits. repaired iaw srm-000. area secure and fod free. pema: 6cksa67629  '),
#  ('worn upper blue pcr bolt', 'all parts recieved. placed in w/c 110 cage.'),
#  ('gbc 280 present fwd linear bladefold transducer bad          ',
#   'removed and replaced fwd transcducer iaw 140-300. blade fold worked as advertised iaw gai-010. area fod free and secure.  '),
#  ('blue pitch lock housing saftey wire incorrect.',
#   'saftey wired blue pitch lock housing iaw 150-300. all checks good. area secure and fod check complete.'),
#  ('all six tires have low air pressure.          ',
#   'serviced tires iaw sss 1210. used pema 67332. ataf. apaf. aff.  '),
#  ('small hole in black tail rotor boot.          ',
#   'sealed small hole in black tail rotor boot iaw srm-000. ataf. area secure and fod free.  '),
#  ('mrh accumulator hyd low          ',
#   'mrh fluid gage is indicating low low green. mrh accumulator is within limits iaw gai-000 servicing check-mrh accumulator, step b. area secure and fod free at time of inspection. ng 1500 psi  '),
#  ('mrh aft scissors have side to side play.          ',
#   'shimmed aft scissor iaw 150-300. pema: 6fksa76012. area secure and fod free.  '),
#  ('remove  fwd scissor  to facilitate the removal of main rotor head for  swashplate removal and replacement re-install fwd scissor when notified by maintenance control.',
#   'removed and re-installed fwd scissor  to facilitate the removal of main rotor head for  swashplate removal and replacement. area secured. fod check complete at time of inspection.'),
#  ('mrh hyd low - touching white on low green side          ',
#   'serviced mrh to second green 1650 psi. outside air temp 26c current a/c hours 3646.4. area corrosion and fod free. refer to mcn 00cdq2a for conditional. pema 6fksa75963.  '),
#  ('mrh accum hydraulic side is low with indicator on the line at red. card 47.1          ',
#   'serviced mrh accumulator iaw gai-000. hyds in the yellow. nitrogen is at 1450 psi. outside abient temperature is at 18 degrees celcius. aircraft flight hours are at 2,907.5. conditional required. refer to mcn: 00cczi1. area clean and fod free. pema-6fksa7'),
#  ('red, yellow, and black tail rotor pcl attaching bolts have washers installed incorrectly on bolt head side.          ',
#   'removed and installed red, yellow, and black pcl attaching bolts and washers iaw 150-300. area fod free and secure. refer to jcn: q60136412 for 9-13 tq checks  '),
#  ('emergency landing gear blow down bottle under serviced',
#   'serviced emergency landing gear blowdown bottle iaw sss 1210. ataf apaf aff. pema 7344'),
#  ('main rotor vibes out of limits.',
#   'performed main rotor head pcr adjustments iaw a1-h60rs-vib-200. adjusted yellow blade +3 and adjusted black pcr -2. area secure and fod free at time of inspection.'),
#  ('red main rotor blade corroded: weight block in several spots, corrosion on blade surface at the bottom trainling edge and tip cap mount flange corroded card bd-95.1 step 2.4 / 2.5',
#   'removed and replaced red blade iaw 150-300.  area secure and fod free.  pema s/n: 8fkka48475. refer to jcn: by0323199 for intial torque and jcn: by0323200 for 9-13 torque check on tip cap.'),
#  ('aft scissor hardware worn.',
#   'removed and replaced h/w on aft scissior iaw a1-h60ra-150-300. area secure and fod free at time of completion.'),
#  ('blade fold inop.',
#   'removed and replaced blade fold control panel iaw reference: a1-h60ra-150-300.  op-checks 4.0 iaw reference: a1-h60ra-420-200.  area secure and fod free at time of inspection.'),
#  ("both left and right brakes are extreamely soft. brakes won't hold plane at 60 nacelle angle when proprotors are spinning.*** while bleeding brakes found brake bleed valve packings worn***          ",
#   'refer to mcn: 2x3x77c for replacement of packings and bleeding of mlg brake system. ataf, apaf, aff. pema2403.  '),
#  ('mrh hydraulic side low',
#   'serviced main rotor head accumulator hydraulics using hsu 262 navy class 2. hydraulic side is at high green. nitrogen is at 1600 psi. within limits iaw a1-h60ra-gai-000. a/c time: 2230.6 oat 25*c. area secure, clean and fod free. refer to conditional mcn:'),
#  ('rh nlg tire is worn          ',
#   'removed and replaced r/h nlg tire iaw sss3240. ataf apaf aff  '),
#  ('outbord black damper bearing worn beyond limits          ',
#   'removed and replaced outbord black damper bearing iaw a1-h60ra-150-300 wp16. area cleaned and fod free. ietms48953.  '),
#  ('install red main rotor blade for pmi restore.          ',
#   'installed red main rotor blade iaw a1-h60ra-150-300. area secure and fod free at time of inspection.  '),
#  ('main rotor head accumulator hydraullic pressure gauge line worn out of limits.          ',
#   'parts received. refer to mcn:25b7qc6 for installation. iaw mrc-400. pema 7959. area secure and fod free.  '),
#  ('safety wire broken on lock pin puller (yellow blade)          ',
#   'verified broken safety wire on yellow lock pin puller, all pieces accounted for. verfied torque of nut, torque checks good iaw 150-300.re safety wired. area fod free and secure at time of inspection. pema:3  '),
#  ('cannibalized item: main rotor accumulator assy (ddsn: 8010gc51) for modex 702 original mcn: 1wda0x0          ',
#   'installed mrh accum iaw 150-300 and gai-000 using n-2 wab s/n: 127 and hsu s/n: 204 (navy class: 2). mrh is at 1700 psi high green, oat: 18 degrees celcius. a/c hours time now : 3272.1 accumulator checks good at time of inspection. area fod free and secu '),
#  ('red tail paddle pcl out of limits and needs to be adjusted.',
#   'adjusted red tail paddle pcl iaw a1-h60ra-140-300.  new measurement is 3 degrees. utilized rig kit s/n: lke-5182-059 and daps s/n: 8407-0010. area secure and fod check complete.'),
#  ('fwd rivet on red tail paddle tip cap corroded',
#   'removed and replaced red tail paddle rivets iaw 150-300 and 01-1a-8. area secure and fod free. pema 27978.'),
#  ('grinding noise and visible vibrations originating from black blade spindle while cycling flight controls.          ',
#   'inspected spindle iaw 150-300. found that black spindle droop stop ring was grinding internally. applied lubrication and binding is no longer present. waited 10 minutes and cycled flight controls again, no binding noted. area secure and fod free. used pem'),
#  ('tail rotor is out of limits          ',
#   'added 99 grams to qd 1 added 39 to quad 4. iaw vib-200 area secure and fod free. pema 6fksa76279.  '),
#  ('mrh accumulator low.          ',
#   "performed bleed and service  iaw a1-h60ra-gai-000. utilized n2 bottle sn:210, hsu sn:210. serviced hydraulic gauge to yellow and nitrogen to 1500 psi @ oat 30c. time last serviced 1018.4  time now 1098.2. area fod free and secure. hsu navy class '0'  "),
#  ('right hand nose landing gear tire is worn          ',
#   'replaced rh nlg tire iaw sss 3240. ataf, apaf, aff. used pema 67371  '),
#  ('da over serviced ***update***da is bad, fluid is coming out of nitrogen port on hydraulic side.          ',
#   'removed and replaced d/a iaw 150-300, gia-000. tqw# 8756.  '),
#  ('black lower centering socket loose          ',
#   'reshimmed black lower centering socket iaw 150-300. area clean, secure and fod free.  '),
#  ('rh nlg tire worn beyond limits due to lh nlg tire being replaced.          ',
#   'replaced rh nose landing gear tire iaw sss 3240 utilizing pema 01112 ataf apaf aff.  '),
#  ('main rotor accumulator low          ',
#   'serviced mrh accum iaw gai-000. hyd side: yellow nit press: 1450. area clean, secure and fod free. pema serno 6739.  '),
#  ('low mrh accumulaotr hydraulic fluid.          ',
#   "main rotor head properly serviced iaw gai-000. hyd: yellow. nit: 1700. 38 c'. time: 475.6 hrs , area secure fod check complete.  "),
#  ('aft scissors spherical bearing worn ool',
#   'removed and replace aft scissors sphearical bearing iaw a1-h60ra-150-300.area secure and fod check complete.'),
#  ('landing gear fault posted airborne after putting gear down on final landing to miramar. indicated 3 down and locked with no other unsafe indications. landing gear isolation valve f(p) on maint flight summary. nothing posted on pres sys stat. executed no h',
#   'performed wire checks fromm fcc 3 to landing gear iso valve iaw ietm sss troublshooting task 2921f8fi 03. system works as advertised. all wire checks are good to include internal resistance checks into the landing gear iso valve. pema 02100 was used.ataf '),
#  ('service mrh accumulator          ',
#   'serviced mrh accumulator iaw a1-h60ra-gai-000. hyd level:high green nitrogen:1530psi ambient temp:20celcius a/c time 3766.100. area secure and fod free at time of inspection.  '),
#  ('mrh low          ',
#   'serviced main rotor head accum iaw gai-000. area secure and fod free. oat: 10 degrees c. fluid: top of lower green. nitrogen: 1450psi.  '),
#  ('main rotor head accumulator nitrogen side low at 1350 psi.          ',
#   'serviced main rotor head accumulator iaw: a1-h60ra-gai-000. hydraulic gauge reads top of yellow & nitrogen reads 1600 psi. oat: 27*c a/c time: 2264.3 all checks good. area fod free and secure at time of completion.  '),
#  ('damper bolt worn ool. (b-101.1)          ',
#   'removed and replaced bolt iaw 150-300. area fod free and secure.  refer to phase b mcn: 40b9u4f for installation.  '),
#  ('outbd retention plate is gouged out of limits the limit is .100 and it is at .231 card number 70.1          ',
#   'removed and replaced outboard retention plate iaw a1-h60ra-150-300. area secure and fod free.*** correction: torque outboard retention plate bolts to 55 ft lbs iaw 150-300***  '),
#  ('mrh accum low          ',
#   'serviced mrh accumulator to yellow at 1500 psi  iaw gai-000. hsu 300 navy class: 0. a/c time is now: 2243 , oats: 10 c. all checks good, area fod free and secure.  '),
#  ('tail rotor vibes ool.          ',
#   'performed vibration analysis on tail. added 25gram to quad1, 61gram to quad2 iaw vib-200. area secure and fod free.  '),
#  ('remove and replace the nose landing gear drag strut in order to incorporate afc 185.          ',
#   'removed and replaced nlg drag strut iaw sss 3220 pema 1531 preformed hyd analysis utilizing the pods method sys 3 ran navy class 0 all checks good  '),
#  ('aft mr scissor spherical bearing worn ool.          ',
#   'removed and replaced aft mr scissor sperical bearing iaw a1-h60ra-150-300. area secure and fod check complete.  '),
#  ('remove red main rotor blade tip cap assy as match set with main rotor blade.          ',
#   'removed red main rotor blade and tip cap assy as a matched set. tip cap will be turned into supply attached to main rotor blade assy. used pema 4ktya45034. area clean and fod free.  '),
#  ('main rotor head fluid level low          ',
#   'serviced mrh accumulator to the low side of the high green iaw: a1-h60ra-gai-000. using hsu s/n 275 pulling a navy class 2. nitrogen pressure remains at 1650 psi. all checks good. area fod free and secure at time of completion.  '),
#  ('missing safety wire on black droop stop heater pin.          ',
#   'replaced safety wire iaw 150-300. refer to jcn: pq4256895 for fod search. area secure and fod free.  '),
#  ('mrh hyd lvl red          ',
#   'serviced mrh accumulator iaw gai-000. hyd level on high green, nitrogen pressure 1600 psi, and oat 14 degrees celcius. a/c hours of 3,068.6. area secure and fod free at the time of completion.  '),
#  ('worn droop stop on blue main rotor blade. mrc-400 card d-121.2',
#   'removed and replaced worn droop stop on blue maint rotor blade iaw 150-300. all checks good. area secure and fod free at the time of inspection. refer to q20259a37 for indexed part. pema 76544.'),
#  ('inboard tip cap delaminating on blue paddle.          ',
#   'inspected blue paddle tip cap iaw srm-000. tip cap rivets are slightly worn but still secure. area fod free and secure at time of inspection.  '),
#  ('black mrb bim indicator is leaking.          ',
#   'removed and replaced black mrb bim indicator and serviced blade iaw 150-300.  area secure and fod free.  '),
#  ('tail vibes out of limits',
#   'added weight to tail quadrant 1: 11 grams, quarant 2: 223 grams iaw vib-200. pema: 7879. area secure and fod free.'),
#  ('install number 6 lower tip cap screws',
#   'installed number 6 lower tip cap screw iaw: a1-h60ra-150-300. area secure and fod free at time of completion.'),
#  ('yellow inboard damper ool.',
#   'removed and replaced inboard yellow damper bearing iaw a1-h60ra-150-300. area fod free and secure at time of inspection.'),
#  ('blue tail rootor boot has a hole          ',
#   'applied sealant on blue tail roter boot iaw smr-000. area clean and fod free.  '),
#  ('black tail rotor paddle has loose ziptie',
#   'inspected black trb zip tie. tightened zip zie. checks good iaw 150-300. area secured and fod free at time of inspection.'),
#  ('remove blue main rotor blade to be replaced with yellow main rotor blade.',
#   'removed blue main rotor blade iaw a1-h60ra-150-300 wp 028. installed yellow mrb on the blue spindle iaw a1-h60ra-150-300 wp 028. tq blade to 282 ft-lbs and applied safety wire.'),
#  ('black t/r blade boot cut torn.          ',
#   'removed and replaced black tail rotor blade boot iaw a1-h60ra-150-300. area fod free and secure.  refer to jcn: qg0219287 for blk tail pcl 9-13.  '),
#  ('mrh accumulator reads red.          ',
#   'serviced mrh accumulator iaw gia-000. hyds serviced to high green, nitrogen to 1600 psi, oat: 16 degrees celcius. area is secure and fod free at time of completion.  '),
#  ('left hand/right hand main landing gear inboard and outboard tire and left and right nose landing gear tire pressures low.          ',
#   'serviced lh and rh ib/ob mlg tires and lh and rh nlg tires to proper pressure iaw sss 1210. used pema 67341. ataf apaf aff.  '),
#  ('aft scissor ball bearing worn.          ',
#   'removed and replaced aft scissor bearing iaw 150-300. area fod free and secured at time of inspection.  '),
#  ('rh nlg tire worn beyond limits.          ',
#   'removed and replaced rh nlg tire iaw sss 3240. ataf apaf aff. used pema 76580  '),
#  ('blue pitchlock actuator will not drive out.          ',
#   'refer to mcn: 00jcrce, jcn: qg0080535 for corrective action. area fod free and secure at time of inspection. ******refer to mcn 00jc9oh for parts complete. could not change wuc because parts were complete. black blade was selected vice blue*****  '),
#  ('blue tail rotor blade seal boot has a hole in it.          ',
#   'rremoved and replaced blue tail rotor blade seal boot iaw 150-300. area secure and fod free.  '),
#  ('main rotor head low.          ',
#   'serviced main rotor head accumulator with mil-prf-83282 iaw a1-h60ra-gai-000 using hsu s/n: 262, navy class 0. hydraulic gauge is at the bottom of the yellow. nitrogen gauge is at 1550 psi. oat reads: 25 degrees celcius. area clean and fod free at time of'),
#  ('left hand nose landing gear tire worn          ',
#   'removed and replaced left hand nose landing gear tire iaw sss 3240. ataf apaf aff.  '),
#  ('red spindle elastomeric bearing is worn out of limits.          ',
#   'removed and replaced red blade elastomeric bearing iaw a1-h60ra-150-300. area secure and fod free.  '),
#  ('main rotor head accumulator fluid low.          ',
#   'serviced main rotor head accumulator iaw gai-000.  hyd side middle second green, ntiro 1600, oat 29c. a/c flight hours: 2036.800.  area secure and fod free at time of inspection. pema: 27569.  '),
#  ('mrh accumulator hyd side is low.          ',
#   'removed and replaced main rotor head accumulator iaw a1-h60ra-150-300. performed full bleed and service iaw a1-h60ra-gai-000. accumulator hydraulic side is at bottom of second green at 1600 psi of n2. oat is 26 degrees celsius. pema 53 s/n 6fksa76277. are'),
#  ('black journal bearing out of limits.  d-121          ',
#   'removed and replaced black spindle iaw a1-h60ra-150-300. torqued bolts to 80 ft/lbs or 960 in/lbs. area secure and fod free at the time of inspection. pema: 14925  '),
#  ('nose landing gear bellcrank assembly broken.          ',
#   'replaced nose landing gear bellcrank assembly iaw sss 3220. pema 2506. ataf. apaf. aff.  '),
#  ('corrosion on t/r pitch beam bushings. none allowed. mrc-400 card ac-70          ',
#   'cleaned tr pitch beam iaw 01-1a-509, inspected tr pitch beam bushing iaw mrc-400. no corrosion found. area secure and fod free.  '),
#  ('yellow pcr torque stripe worn          ',
#   'applied torque stripe on yellow pcr. checks good iaw 150-300. area secure and fod free at time of inspection.  '),
#  ('yellow blade fold harness does not power blade fold motor. troubleshot iaw 560-200. yellow blade fold harness needs to be replaced.          ',
#   'removed and replaced yellow blade fold harness iaw 150-300. op checks good iaw 150-200. pema 21-6cksa67642.  '),
#  ('main rotor head low          ',
#   'main rotor head accumulator is within limits (did not require servicings) iaw a1-h60ra-gai-010.  hyd fliud side is at middle of first green, 1450psi and 19 degrees celsius. area secure, clean, and fod free. pema s/n 7iksa25995.  '),
#  ('blue main rotor damper hydraulic line chafed down to the metal braid          ',
#   'removed and replaced blue main rotor damper hydraulic line iaw 140-300. area clean and fod free. pema s/n: 6cksa75997.  '),
#  ('rh/lh nlg low tire pressure          ',
#   'rh/lh nlg tires serviced iaw sss 1210 ataf apaf aff pema 67347  '),
#  ('mrh low          ',
#   'serviced mrh accumulator iaw 150-300 and gai-000. hsu s/n:284 navy class 0. pods s/n:00183.  hyd side: middle high green, nitrogen 1600, oats 22c. last flight hours:3387.1. acft hours now 3399.1. no conditional required.area secure and fod free.  '),
#  ("exterior landing gear down light is f(p) and light won't illuminate.          ",
#   'replaced exterior landing gear down light bulb iaw ietms sss 3260. system op checks good. aff ataf apaf.  '),
#  ('mrh accumulator  low',
#   'serviced mrh damper accumulator with mil-prf-83282 iaw a1-h60ra-gai-000. serviced to low high green, 1650 psi. oat 23 degrees celsius. navy class 2. area fod free and secure at time of inspection. a/c time now: 2704.3'),
#  ('tr bias ool          ',
#   "performed tail rotor 3 degree bias. blue and yellow pcl's within limits. made adjustments to red and black pcl's to obtain 3.0 degree pitch +/- 0.1 degree iaw 140-300 using pema s/n: 6019. area secure and fod free at time of inspection.  "),
#  ('fwd scissor on main rotor head has up and down play.          ',
#   'measured forward scissor up and down play iaw 150-300. movement was measured at .013 and limits is .033. movement within limits. area secure and fod free. pema s/n: 6fksa76012.  '),
#  ('tail vibes ool',
#   'added 60g to quadrant 1 and 120g to quadrant 4 iaw the onboard station and a1-h60rs-vib-200. area secure and fod free at time of inspection. pema s/n: 6cksa67512.'),
#  ('main rotor head over serviced',
#   'properly serviced mrh accum iaw gai-000. hyd side: second green, nitrogen side: 1500 psi. area secure, clean, and fod free. pema 6fksa75955.'),
#  ('perform card abcd-30-30.1 post phase vibration analysis and data review          ',
#   'performed ground vibration analysis iaw vib-200. all vibes check good, area fod free and secure.  '),
#  ('yellow blade disbonding of nickel abrasion strip.on under side of blade.          ',
#   'removed and replaced yellow blade  iaw: a1-h60ra-150-300. pema used 2743, area secure and fod free.  '),
#  ('the mrh hyd accumulator reads red          ',
#   'serviced mrh iaw a1-h60ra-gai-000. hyd at high green, nit at 1450 psi, oat 23 degrees celcius a/c time: 1948.9. area secure and fod free.  '),
#  ('yellow blade has tip cap frame spliting due to severe expoliation.          ',
#   'removed and replaced yellow main rotor blade iaw 150-300. area clean and fod free. ataf  '),
#  ('lh nlg tire is worn beyond limits',
#   'removed and replaced lh nlg tire iaw sss 3240. ataf apaf aff.'),
#  ('yellow damper is leaking          ',
#   'inspected yellow main rotor damper iaw a1-h60ra-150-300.  leak is coming from differential check valve screw.  leakage is allowed per a1-h60ra-150-300 wp16 step e. 3a.  pema s/n 2922.  area secure and fod free.  '),
#  ('mrh accumulator low (hyd)          ',
#   'serviced mrh using hsu 216 navy class 0 pods 0458 iaw: a1-h60ra-gai-000, all checks good. hyd high green, nitrogen is at 1600 psi.  oat is 20 degrees celsius. a/c hours hours 2606.8 conditional n/a. area clean and fod free at time of completion.  '),
#  ('blue lower centering socket still loose.          ',
#   'removed safety wire, torqued one bolt on plug iaw a1-h60ra-150-300. no movement was made at 15 inch lbs. resafety wired. area secured and fod free at the time of inspection.  '),
#  ('mrh accumulator low          ',
#   'serviced mrh accum to 2nd green iaw gai-000. nitrogen at 1700 psi oat 23 degrees celcius. current flight hours: 2717.5. no conditional required. area secure and fod free. pema 6cksa67650.  '),
#  ('black reduction gear housing seized card d-114.',
#   'removed and replaced black reduction gear housing iaw 150-300. fod and corrosion checks complete. all secure. pema 18-6fksa75997'),
#  ('main rotor head vibe out of limit.          ',
#   'adjusted red pcr up 5 clicks, blue pcr down 15 clicks and yellow pcr down 5 clicks iaw: vib-200 and 150-300. refer to mcn: 46sixlb jcn: qv0362306 for 9-13 on blue, yellow, red. area secure and fod free at the time of inspection.  '),
#  ('red upper centering socket worn ool. d-119          ',
#   'removed and replaced red upper centering socket iaw reference: 150-300. area secure and fod free at time of inspection.  '),
#  ('mrh accum low.',
#   'main rotor head serviced with hsu 270 navy class 0 to yellow 1550 psi iaw: a1-h60ra-gai-000. oat: 28 degrees celcius. excessive leakage maf: qy0169404. area secure and fod free at time of completion. a/c time now: 2321.0'),
#  ('mrh accumulator low.          ',
#   'serviced main rotor head accumulator iaw a1-h60ra-gai-000. hyd: yellow. n2: 1500 psi. a/c hours: 605.5. oat: 29 degrees celcius. area secure and fod free at time of inspection.  '),
#  ('hole in red tail rotor boot.',
#   'applied sealant on hole in red tail rotor boot iaw srm-000. area secure and fod free.'),
#  ('left hand and right hand main landing gear tire pressures low.',
#   'serviced all mlg tires iaw sss 1210. ataf apaf aff. used pema 67330'),
#  ('mrh accumulator low          ',
#   'serviced mrh accumulator to 1500 psi high green at 10 degrees celcius iaw gai-000. all checks good. area fod free and secure. aircraft time now: 4103.9.  '),
#  ('mrh accumulator low **backfit**          ',
#   'serviced mrh accumulator iaw a1-h60ra-gai-000 to yellow 1600 psi o.a.t. 20 degress celcius. area secure and fod free at the time of inspection. used hsu 216 navy class 0.  '),
#  ('black reduction gear housing (gears) internally corroded and barring snapped . card d-121.3 step 12.1          ',
#   'cannibalized (buno: 168101 mcn: 1xlm1an) removed and replaced black reduction gear housing iaw 510-300. refer to jcn: q60068572 for opcheck. area is fod free and secure.  '),
#  ('left hand out board mlg tire tread is worn out of limits          ',
#   'removed and replaced lh ob mlg tire iaw sss 3240. used pema 67339. ataf apaf aff  '),
#  ('during gen underfreq check #1 eng torque was 45% higher than #2 eng.  there is also a torque split as the pcls are evenly advanced to fly. suspect lds rigging issue.          ',
#   'performed lds and pas rig checks on #1 and #2 engine iaw 220-300. rig checks good, no discrepancies noted. area is fod free and secured. pema s/n: 6fksa76012  '),
#  ('forward scissor assy is ool.          ',
#   'removed and replaced forward scissor assy iaw 150-300.  area secure and fod free.  '),
#  ('np shadowed nr on second and third attempts to auto. after observing, we coupled back up and waved off. saw np as high as 104.',
#   'np is within operational limits iaw gai-000. limits are  max continuous-  105.2% // 20 second transient- greater than 105.2% // 12 second transient- 117.2% // maximum- 121%. area secured and fod free.'),
#  ('worn torque stripe on aft scissor bolts',
#   're applied torque stripe to aft scissor bolts iaw 150-300. area secure and fod free at time of inspection.'),
#  ('wow disagree with nose sw 2 f(p) posted once with it. ts to nlg wow proximity sensor          ',
#   'removed and replaced nlg wow proximity sensor no. 2  iaw ietems sss:3220. for op check refer to mcn/jcn: 4dnq1tj/gdl136087. ataf. apaf. aff.  '),
#  ('install yellow blade fold actuator. refer to document number 8045gs43 for turn in documentation.          ',
#   'installed yellow blade fold actuator iaw 150-300. refer to mcn: 2e4fy3g jcn: am0045039 for fold harness and switch installation. area secure and fod free.  '),
#  ('lh nose tire worn          ',
#   'removed and replaced lh nose tire iaw sss 3240 ataf apaf aff.  '),
#  ('remove and replace component nomenclature main rotor head damper assy;  part no: 70106-28000-048;  serno: a221-02913;  pos cd: red          ',
#   'removed and replaced red damper iaw: a1-h60ra-150-300. area secure and fod free at the time of inspection.  '),
#  ('red mrh damper outboard bearing worn out of limits          ',
#   ' removed and replaced red mrh damper outboard bearing iaw a1-h60ra-150-300. area secure and no fod found. refer to mcn: 1v4yz1m for 9-13 flight hour torque check.  '),
#  ('verify all landing gear door rigging and perform emergency blow down bottle op check.          ',
#   'performed emergency extention test iaw sss:3221, pema sn:44688, cameo version:1.3.10. area fod free.  '),
#  ('rh nose landing gear tire worn beyond limits          ',
#   'rh nose landing gear tire removed and replaced iaw sss3240 ataf, apaf, aff. pema used 1913  '),
#  ('during rotor spread, yellow blade stayed in the fold position. attamped steps as per pcl and recommended by the ae. used two different cheater boxes to finally get blade in the spread position. spread incomlete light remained on. head check was good and f',
#   'refer to mcn:25b7y15 for duplicate gripes corrective action.  '),
#  ('blue mrb hinge cam follower is seized. (abcd card- 23)',
#   'removed and replaced blue hinge cam follower iaw a1-h60ra-150-300. area is secure and fod free. pema 8884'),
#  ('blue damper leaking          ',
#   'refer to jcn a21219409 for excess leakage of damper conditional.  area secure and fod free at time of inspection.  pema 7521  '),
#  ('worn red paddle abrasion strip. ool.          ',
#   'replaced abrasion strip on red paddle iaw 150-300. checks good. area fod free and secure at time of inspection.  '),
#  ('main rotor head accumulator low          ',
#   'serviced main rotor head accumulator to yellow, nitrogen 1500psi iaw a1-h60ra-gai-000. area is secure and fod free. used pema sn 5fkya30703.  '),
#  ('mrh acc low (low, 1 green)',
#   'inspected mrh accum iaw gai-000. mrh accum is in the first green at 1600 psi. mrh accum is within limits. area secure and fod free. ietm sn 6fksa75963.'),
#  ('tail rotor vibes out of limits.',
#   'performed tail rotor adjustment, removed 136 grams from quadrant 1 and removed 68 grams from quadrant 4 iaw a1-h60ra-vib-200. area secure and fod free at time of inspection.'),
#  ('mrh red blade bim indicator  showing black.',
#   'inspected red mrh blade bim indicator iaw 150-300. red mrh blade bim is within limits at 8 psi at 13Â¿c. area secure and fod free at time of inspection. used check and fill unit s/n: 62059-14.'),
#  ('hole in the blue tail rotor boot. card 11.12          ',
#   'repaired blue tail paddle boot iaw srm-000.  area secure and fod free.  pema 6cksa67629.  '),
#  ('perform tail rotor balance          ',
#   'performed tail rotor balance iaw vib-200. vibes within limits. fcp is lt c murphy. area clean, fod free and secure. pema#6fksa75970.  '),
#  ('incorrect safety wire on red blade fold stop switch          ',
#   'removed and replaced safety wire on red blade fold stop switch iaw 01-1a-8. all checks good. area secure and fod free at the time of inspection.  '),
#  ('black  elastomeric bearing center ring gauged ool.          ',
#   'removed and replaced black elasto iaw 150-300. area fod free and secure. refer to jcn: qgo149393 and mcn: 00jf9ju  for 9-13  '),
#  ('hole in tail rotor boot, blue paddle. mrc-300. card 11.12.          ',
#   'repaired blue tail rotor boot iaw a1-h60ra-srm-000. area secure and fod free at time of inspection.  '),
#  ('abrasion strip on black tail rotor slightly disbonding.          ',
#   'duplicated maf. refer to mcn: 00jdi76 blk trb abrsn strip torn  '),
#  ('aft main rotor head swashplate scissor assebly is worn out of limits.',
#   'removed and replaced aft main rotor head swashplate scissor assembly iaw a1-h60ra-150-300. area fod free and secure.'),
#  ('admin install blue pitch lock motor when directed by maint control.',
#   'installed blue pitch lock motor iaw 150-300.  refer to jcn by0164034 for opcheck of blue pitch lock and blade fold. area secure and fod free.  pema 8fkka48475'),
#  ('main rotor head hydraulic servicing low          ',
#   'serviced main rotor head hydraulic accumulator to second low green and 1550 psi of nitrogen at 67 degrees fairinhiet in accordance with a1-h60ra-gai-000. area clean secure and fod free. pema 6fksa75795 was used. current aircraft hours 547.5. no further ac'),
#  ('red elastomeric bearing new shim size requires size 18 bolt.          ',
#   'remeasured elastomeric bearing iaw 150-300. shim size requires size 17 bolts . area is clean and fod free.  '),
#  ('tail rotor balance vibration out of limits.          ',
#   'removed and replaced blue and black tail paddle iaw:150-300. reffer to ground vibes maf jcn:00jdbqt and reffer to new 9-13 jcn: 00jdbxf/ jcn:00jdbxg/ jcn:00jdbxi. area fod free and secured.  '),
#  ('tail rotor indexer cam broken.  part turned into m/c.',
#   'removed and replaced tail rotor indexer iaw 150-300 wp 27.  checks good iaw 150-200.  area fod free and seucre.'),
#  ('main rotor head accumulator low          ',
#   'serviced mrh accumulator iaw gai-000. hyd: high green; nitrogen: 1600psi; oats: 19c; aircraft hours: 2,2679.0. no conditional required. area fod free and secure.  '),
#  ('black blade lower center socket loose.          ',
#   're-shimmed black blade lower centering socket iaw 150-300. area secured and fod free.  '),
#  ("black blade hinge 12 o'clock , 3:o'clock  and 8 o'clock position inserts , failed insert checks.          ",
#   "removed and replaced black blade hinge 12 o'clock , 3:o'clock  and 8 o'clock position inserts iaw a1-h60ra-150-300. checks good. area secured and fod free at the time of the inspection. refer to mcn 00jehlx jcn qg0025134 for installation of black mr blade"),
#  ('cut in sidewall of lh nlg tire',
#   'removed and replaced lh nlg tire iaw sss 3240. ataf, apaf, aff, pema 2249.'),
#  ('mrh accumulator low.          ',
#   'serviced main rotor head fluid level with hsfu s/n: 291 to yellow and nitrogen pressure to 1450 psi iaw gai-010. ambient temperature was 32 degrees celsius. area secure and fod check complete.  '),
#  ('mrh accumulator fluid level low          ',
#   'serviced mrh accum iaw a1-h60ra-gai-000. hyd side in high green,  nitrogen at 1450 psi, oat is 23 degrees celsius, aircraft time is 2,433.1.  hsu s/n: 245. area secured and fod free.  '),
#  ('main rotor head out of limits',
#   "adjusted mrh pcr's red pcr: 6 clicks up, blue pcr: 7 clicks down and yellow pcr: 11 clicks down iaw vib-200. area secure and fod free at time of inspection. pema 6cksa67524."),
#  ('d-121. hub insert failed run-on tq checks          ',
#   'removed and replaced hub insert iaw 150-300. area fod free and secure.  '),
#  ('found rh main outboard landing gear tire is out of limits.          ',
#   'removed and replaced rh mlg ob tire iaw sss 3240. ataf. apaf. aff.  '),
#  ('replace yellow main rotor blade tip cap as match set with mrh blade.  bd-95.1          ',
#   'removed and replaced yellow main rotor blade tip cap as match set with mrh blade iaw 150-300. area secure and fod free.  '),
#  ('forward x-pin worn beyond limits.',
#   'received fwd x-pin will install when bridge is installed iaw a1-h60ra-mrc-350. area clean and fod free. refer to mcn 2e4h6m3.'),
#  ('tail rotor pitch beam corroded beyond limits          ',
#   'removed and replaced tail rotor pitch beam iaw 150-300. area is clean and fod free. pema s/n:6cksa67609  '),
#  ('scir change:  00cfv7e.  yellow blade fold motor bad.',
#   'removed and replaced yellow blade fold motor iaw 150-300. area secure and fod free. pema: 6fksa76035 refer to mcn: 00cg2rm for switch adjustment and blade fold motor op check.'),
#  ('tail rotor pitch control link jamnuts are corroded.  ref: a1-h60ca-mrc-400 card abcd-29.          ',
#   'removed all corrosion from pcl jamnuts in accordance with 01-1a-509-2. area fod free and secure at the time of inspection.  '),
#  ('red main rotor droop stop has impact damage ool. ref: a1-h60ra-mrc-400 card-d-121.2',
#   'all red droop stop parts received. refer to phase "d" mcn: 26xj7y9 jcn: qy0063a00 for installation. ***consumable parts indexed***'),
#  ('black blade bumper hardware worn',
#   'replaced black blade bumper hardware iaw a1-h60ra-150-300. area secure and fod checks complete  at time of inspection.'),
#  ('main rotor head hydraulic level low.',
#   'serviced mrh accumulator hyd: yellow// n2:1400//temp: 18c iaw gai-000. all checks good area secure and fod free at time of completion.'),
#  ('aft scissor spherical bearing ool          ',
#   'verified aft scissor spherical bearing was within limits iaw a1-h60ra-150-300 wp 17. limit .033 in. observed play was .027 in. area secure. fod checks complete.  '),
#  ('main rotor head damper accumulator fluid level is low.          ',
#   'serviced main rotor head accumulator iaw gai-000. hydraulic fluid level at the bottom of the second green. nitrogen side at psi 1600 psi. oat degrees 25 celcius. current flight hours 3121.1. area secure, clean, and fod free. pema 6fksa75963. refer to mcn:'),
#  ('rh mlg door strut worn          ',
#   'removed and replaced right hand mlg door strut. iaw sss 3210. ataf apaf aff pema 7  '),
#  ('red pcr torque stripe worn          ',
#   'applied torque stripe on red pcr. checks good iaw 150-300. area secure and fod free at time of inspection.  '),
#  ('perform ground vibes',
#   'perfromed ground vibs iaw vib-200. all ground vibs in limits area secure and fod free.'),
#  ('red lower centering socket loose.          ',
#   'red lower centering socket play is within limits iaw 150-300. pema: 6fksa76012. area secure and fod free.  '),
#  ('tail rotor out of limits.          ',
#   'made the following adjustments to the tail rotor: quad 2 +25g and quad 3 +95g iaw vib-200. area secure and fod free. pema 6fksa76012.  '),
#  ('main rotor head damper accum assy servicing ool.          ',
#   'serviced main rotor head damper accum assy hydraulics iaw a1-h60ra-gai-000. servicing is in the low green, just below the yellow section, nitrogen 1750 psi. oat 26*c. a/c time 2382.1. time since last servicing 10.8 hours. area secure and fod free.  '),
#  ('blue blade pitch lock actuator siezed.',
#   'scir change close-out.  refer to mcn: 00jfouo'),
#  ('inflight vibes 140 ool',
#   'adjusted blue pcr (up 3) iaw vib-200. area fod free and secure at time of inspection.'),
#  ('all six aircraft tire pressures low          ',
#   'serviced lh and rh nose landing gear tires, serviced rh ob and ib tires, serviced lh ob and ib  tires iaw sss 1210. ataf.apaf.aff  '),
#  ('yellow lower centering socket is loose          ',
#   'passed tq check at 15 inlbs with wr sn 2052 and safetied iaw 150-300  '),
#  ('tail rotor vibe ool',
#   'perfomred tail rotor vibration adjustments, quadrants as follows: 12 grams in quadrant 3, 77 grams in quadrant 4 iaw a1-h60rs-vib-200. area secure and fod free at time of inspection.'),
#  ('remove and inspect nlg torque tube          ',
#   'removed and replace lh and rh nlg tq tube support fittings iaw sss 3220. ataf, apaf, aff.  '),
#  ('black and red main rotor blade lockpin switches need to be adjusted          ',
#   'preformed automatic fold and spread iaw a1-h60ra-150-200. blade fold system op checks good. could not duplicate discrepancy. pema 4atya83781.  '),
#  ('scir change:  40b9czp.  ccdd 10sep18 all bim tabs corrodd          ',
#   'removed corrosion. cleaned, treated, and painted (sempen) all 4 bim tabs iaw 01-1a-509 series mil-std-2161c. area secure and fod free at time of inspection.  '),
#  ('outboard retention plate worn ool. part is under warranty          ',
#   'replaced outboard retention plate iaw 150-300. area secure and fod free.  '),
#  ('main rotor head accumulator level low.          ',
#   'bled and serviced main rotor head accumulator iaw gai-000. hyd damper level is first green. nitrogen is at 1530. a/c time now is 585.4. ambient air temp is 73. area is clean and free of fod.  '),
#  ('yellow damper qd saftey wire incorrect          ',
#   're-safety wired yellow damper qd iaw a1-h60ra-150-300. area secure and fod free at time of inspection.  '),
#  ('tail rotor boot black blade torn          ',
#   'inspected black tail rotor boot, tear was not within limits iaw srm-000. removed and replaced tail rotor boot iaw 150-300. area fod free and secure at time of inspection.  '),
#  ('replace black pcr upper rod end due to damage found inside inner member.          ',
#   'replaced black pcr upper rod end iaw 150-300. area is clean and fod free.  '),
#  ('t/r vibes ool.          ',
#   'added 69grams to q4 and 15grams to q1 iaw vib-200. area secure and fod free.  '),
#  ('mrh ool          ',
#   'adjusted red pcr -1 click, yellow pcr +3 clicks and black pcr +13 clicks iaw vib-200. area secure and fod free.  '),
#  ('rh nlg tire worn beyond limits          ',
#   'removed and replaced nose landing gear wheel assembly iaw sss 3240 ataf apaf aff 7344  '),
#  ('during emergency extend test rh mlg drag strut actuator would not fully extend. recieved bad mlg strut from supply, part had no src card, all sensors have bent pins and theres excessive play in both bearings.          ',
#   'removed and replaced rh mlg drag strut actuator iaw sss3210 ataf apaf aff used pema 42568  '),
#  ('main rotor head red damper inboard bearing worn out of limits.          ',
#   'removed and replaced main rotor head red damper inboard bearing iaw: a1-h60ra-150-300 pema: 6fksa76277 area is clean secure and fod free.  '),
#  ('lh nose landing gear tire preasure low.          ',
#   ' serviced tire iaw sss 1210. used pema 67331. ataf. apaf. aff.  '),
#  ('blue tail rotor paddle pivot bearing mount bolts corroded. ac-70.3          ',
#   'removed and replaced blue/black tail rotor paddle iaw a1-h60ra-150-300. all checks good. area fod free and secure. refer jcn: q50080401 for adjustment of tail mag pick-up  '),
#  ('main rotor head hyd low. at the 2nd d in add.          ',
# ...
#  ('mrh reads red          ',
#   'serviced mrh accumulator iaw gai-000. hyds: yellow, n2 pressure: 1600 psi at 11 deg cel. current a/c time: 3342.8. all checks good at current temperature. area fod free and secure.  '),
#  ('card abcd:23.5 fwd scissor upper bushing gouge ool.          ',
#   'removed and replaced fwd scissor iaw a1-h60ra-150-300. checks good. area fod free and secure at the time of inspection.  '),
#  ('red tail rotor boot is not seat correctly          ',
#   'red tail rotor boot was reseated corectly  iaw a1-h60ra-150-300. area fod free and secure at the time of inspection  '),
#  ('red outboard damper bearings out of limits. limit is .010 bearing is 0.20. mrc-400 card 101.1          ',
#   'removed and replaced red outboard damper bearing iaw 150-300. refer to jcn: pq4065a00 for damper installation on phase d.  area fod free and secure.  '),
#  ('perform post phase ground vibes',
#   'performed post phase ground vibs iaw vib-200 all vibs within limits to fly. area secure and fod free at time of inspection. pema 7813.'),
#  ('yellow tail rotor boot ziptie not secured',
#   'inspected tail rotor boot iaw a1-h60ra-srm-000 wp 016 00. completed fod check and area secure at time of inspection.'),
#  ('black mrb tip cap cracked on leading edge.          ',
#   'replaced black mrb tip cap iaw a1-h60ra-150-300. area is secure and fod free. pema 6fksa76333.  '),
#  ('main rotor head accumulator low          ',
#   'bled and serviced main rotor head accumulator iaw: a1-h60ra-gai-000 pema: 6fksa76277 aircraft hours 565.9 temp: 29c low green and 1550 psi.  area is clean secure and fod free.  '),
#  ('lh ob tire has a bald spot out of limits',
#   'replaced l/h ob tire iaw 3240 ataf apaf aff. pema 3'),
#  ('mrh accumulator low          ',
#   'serviced mrh accumulator to 1400psi and 2nd green iaw a1- h60ra-gai-000. area clean and fod free. ambient temp: 14 degrees celcius. a/c hours: 224.0  '),
#  ('left outboard mlg tire has no tread.',
#   'lh outboard mlg tire removed and replaced iaw sss 3240. ataf. apaf. aff.'),
#  ('tear in red tail rotor blade boot.          ',
#   'repaired tail rotor boot iaw 150-300. area fod free and secure.  '),
#  ('mrh accumulator hyd reads red',
#   'serviced mrh accumulator iaw gai-000. hyd level on high green, nitrogen pressure 1600 psi, and oat 21 degrees celcius. a/c hours of 3,222.7. area secure and fod free at the time of completion.'),
#  ('mrh accumulator low hydraulic side',
#   'serviced mrh acumm to low, second green, 1700 psi at 31c. current a/c time: 3332.7 . leakage within limits. area fod free and secure at time of inspection. pema s/n: 76035.'),
#  ('left hand nose landing gear tire has excessive chunking.',
#   'lh nlg tire replaced iaw sss3240. ataf. apaf. aff.'),
#  ('remove and reinstall mrh beanie when notified by maintenance control to facilitate the servicing of the mrh accumulator',
#   'removed and reinstalled  mrh distributor iaw a1-h60ra-410-300. witnessed torque of 110 inch lbs on mounting bolts utilizing torque wrench sn:00480. cal. date: 19jul19. applied sealant to mounting bolts iaw a1-h60ra-410-300. area fod free and secure at tim'),
#  ('yellow damper male end quick disconnect worn          ',
#   'removed and replaced yellow damper male end quick disconnect iaw 150-300. serviced main rotor head to the yellow with 1500 psi, oat: 27 degrees celcius, lfh:1865.1, cfh: 1868.0, navy class: 0. area secure and fod free.  '),
#  ('worn centering socket lower',
#   'replaced red lower centering socket iaw 150-300. all checks good. area secure and fod check complete.'),
#  ('abrasion strip peeling off on t/r red padel          ',
#   'reapplied abrasion strip on red trb iaw srm-000. area secure, clean, and fod free. pema 6fksa75963.  '),
#  ('l/h nose landing gear tire worn beyond limits',
#   'removed and replaced lh nlg tire iaw sss 3240. pema-09 was used. ataf. apaf. aff.'),
#  ('mrh ool.          ',
#   'adjusted red pcr - 4 clicks and blue pcr +1 clicks iaw a1-h60rs-vib-200. all checks good. fod check complete and area secure at time of inspection.  '),
#  ('perform ground vibes.',
#   'performed  ground  vibration analysis  iaw a1-h60rs-vib-200. all vibration numbers are within limits. pema: 48100. area secure and fod free.'),
#  ('rh nlg tire assy is worn beyond limits          ',
#   'rh nlg tire assy replaced iaw sss 3240 ataf, apaf, aff. pema used 02382  '),
#  ('yellow damper inboard nylon washer fell when removing damper and is missing. refer to jcn q30028188 for fod search.          ',
#   'found yellow damper inboard nylon washer by qa. refer to mcn: 1v4zfb7 for yellow damper installation.  '),
#  ('main rotor head accumulator out of limits.          ',
#   'serviced main rotor head accumulator to 1650 psi/ second green iaw gai-000 pema 6111. aircraft flight hours: 3,859.4. ambient temp: 79 degrees f. area fod free and secure.  '),
#  ('mrh accumulator low. need full bleed and service.          ',
#   'bled and serviced mrh accumulator iaw 150-300. mrh accumulator: 1600 psi; hyd level: yellow. aiircraft time now: 2026.9 flight hours. ambient air tempature: 89 degrees f. area clean and fod free. pema s/n: 6cksa75997.  '),
#  ('lh nlg tire worn',
#   'replaced lh nlg tire iaw sss 3240. used pema 6684. ataf apaf aff.'),
#  ('low mrh psi mrc-100 step 47.1          ',
#   'serviced mrh accumulator to 1600 psi high green using n2 wab s/n: 334 and hsu s/n: 204 (navy class: 0) with an oat of 9 degrees celcius. time last serviced: 3604.3. time now: 3615.3. area fod free and secure.  '),
#  ('mrh low. 1600 red.          ',
#   'serviced mrh accumulator iaw gai-000.  mrh hyd fluid in mid high green,  nitrogen pressure at 1600 psi,  oat 30 degrees celcius.  area secure and free of fod upon completion. current a/c time is: 2907.7.  '),
#  ('mrh hyd level in the red.          ',
#   'serviced mrh accumulator iaw gai-000. hyd level: high green, n2 level:1500psi and oat:12 deg cel. a/c time: 1107.5. servicing checks good at current temperature. area fod free and secure.  '),
#  ('fwd scissors have up and down play          ',
#   'inspected fwd scissiors iaw 150-300. scissor play within limits. area secure and fod free. pema: 6cksa67629  '),
#  ('right hand outboard mlg tire cut out of limits          ',
#   'right hand outboard mlg tire within limits iaw navair 01-1a-506 ataf apaf aff  '),
#  ('worn tail rotor zip ties.          ',
#   'removed and replaced tail rotor zip ties  iaw a1-h60ra-150-300. area secure and fod checks complete.  '),
#  ('remove beanie to facilitate full bleed of mrh accumulator.  re-install upon completion of maintenance.          ',
#   'removed and reinstalled mrh beanie iaw a1-h60ra-410-300. area secure and fod free at time of inspection.  '),
#  ('mrh accumulator low, needs to be serviced prior to first flight of the day',
#   'serviced main rotor head accumulator iaw a1-h60ra-gai-000 to top of yellow and 1600 psi with hsu 216, navy class 0. oat is 28 degrees celsius. area secure and fod free at time of completion. a/c time now: 3421.3'),
#  ('red spindle lower weight bracket bore corroded. ccdd:9dec19',
#   'removed corrosion, cleaned, treated and preserved red spindle lower weight bracket bore iaw 509 series. area fod free and secure. pema s/n: 5lksa54016.'),
#  ('red pitch lock liner safety wire tubing is deteriorating.          ',
#   'safety wired red pitch lock liner bolts iaw 150-300. area secure and fod free at time of inspection.  '),
#  ('assist wc 110 by removing mrh accumalator to complete zone 2 torque checks          ',
#   'removed and reinstalled mrh accumulator iaw 150-300. performed full bleed and service on the mrh accumulator iaw gai-000. hydraulic guage is yellow. nitrogen 1500 psi. ambient air temp is 20 degrees celcius. current flight hours is 2150.3. refer to mcn: 0'),
#  ('remove tail rotor pitch beam tfom. re-install w/n/b/m/c.          ',
#   'installed tail rotor pitch beam assy. iaw 150-300. area is clean and free of fod. pema 4ktya45034.  '),
#  ('right hand main landing gear inboard and outboard tires require pressure.          ',
#   'serviced lh ib and ob mlg tires to proper pressure iaw sss 1210. used pema 67332. ataf apaf aff.  '),
#  ('left hand main landing gear inboard tire worn beyond limits.',
#   'removed and replaced lh inboard mlg tire iaw sss 3240 utilized pema 2104 ataf apaf aff'),
#  ('main rotor head in flight regimes out of limits          ',
#   'perfromed the adjustment of the yellow pcr -1 click, blue pcr +1 click and the black pcr -5 clicks iaw vib-200. area secure and fod free.  '),
#  ('hole in blue tail rotor boot.',
#   'repaired hole is blue tail rotor boot iaw srm-000. area secure and fod free.'),
#  ('mrh low          ',
#   'serviced main rotor head accumulator iaw gai-000. hyd sample navy class 2. hyds: high green, nitrogen: 1650psi, oats: 28 celsius. area secure and fod free. a/c time now: 2,607.3  '),
#  ('red spindle adjustment bolt worn          ',
#   'removed and replaced red spindle adjustment bolts iaw 150-300. area secure and fod check complete. pema sn 7529  ***fcf not required***  '),
#  ('need to safety wire 3 bolts on yellow pitch lock.',
#   'safety wired the three bolts on yellow pitch lock iaw 150-300.area secure and fod check complete. pema 41-6fksa76075'),
#  ('rh ob mlg tire cut beyond limits less than 1/32 tread left',
#   'rh ob mlg tire removed and replaced iaw sss 3240 pema 02369 ataf apaf aff'),
#  ('nitrogen level low main rotor head. mrc-100 step: 47.1          ',
#   'serviced main rotor head accumulator to 1500 psi high green iaw gai-000, oat: 20 degrees c, using hsu s/n: 204 (navy class 1), n2 wab s/n: 127. time last serviced 3270.1, time now: 3270.1. refer to jcn: q40352103 / mcn: 1wd9zel for excessive leakage condi'),
#  ('mrh in red',
#   'serviced mrh accumulator to 2nd green/1600 psi iaw gai-000. oat 30 degrees celsius. a/c flight hours: 3,879.6. conditional required. jcn:by021907. area secure clean and fod free. pema 6fksa75974.'),
#  ('mrh ground out of limits',
#   'adjusted blue mrh pcr (-11 clicks) iaw vib-200. torqued and safetywired. area fod free and secure at time of inspection. ***check flight required and qa required***.'),
#  ('gust lock, spread incomplete. when control panel is turned on, spread incomplete is indicated.          ',
#   'work order has a wuc malfunction and will not have the correct part or serial number populate in the remove record. refer to mcn: jcn: for the removal and replacement of the main rotor indexer. no maintenencae performed on this maf.  '),
#  ('mrh in flights out of limits.',
#   'adjusted red pcr down 4 clicks and black pcr up 1 click iaw: vib-200. area secured and fod free at time of inspection.'),
#  ('main rotor head accumulator low.          ',
#   'serviced mrh accumulator iaw gai-000. oat: 20c. nitrogen: 1500 psi. fluid level: upper green. a/c time: 2202.8.  '),
#  ('lh mlg door interface assembly and hardware has excessive play where the door strut rod end is attached.          ',
#   'lh mlg door interface assembly hardware  removed and replaced in accordance with sss 3210. pema 02981. ataf, apaf, aff.  '),
#  ('lh drag strut actuator ser no. bec-773 falls in range of suspect ser no. for bad drag strut actuator, bec-543 to bec-848. fst supplied supporting documentation          ',
#   'replaced lh mlg drag strut actuator iaw sss 3210. ataf, apaf, aff.  '),
#  ('yellow damper inboard bearing worn out of limits.          ',
#   "removed and replaced yellow damper inboard bearing iaw 150-300. serviced mrh accum iaw gai-000. ambient temp is 22 degrees celcuis serviced to 2nd green and 1600 psi. no conditional req. refer to mcn 00cfaxo for 9-13's damper maf. area secure and fod free"),
#  ('blue droop stop damaged beyond limits.          ',
#   'removed and replaced blue droop stop iaw 150-300. area clean, secure and fod free. pema s/n:6fksa76326  '),
#  ('main rotor inflights vibes  at 140 out of limits          ',
#   'adjusted red pcr -1 click, blue pcr +3 clicks, added 34 oz  to yellow spindle and removed 24 oz from blue spindle to bring vibrations within limits iaw vib-200. area secure and fod free at time of inspection.  '),
#  ('hardware on tail rotor positioner has heavy corrosion.  ref:  a1-h60ca-mrc-400 card ac-70.1          ',
#   'removed and replaced tail rotor positioner cam hardware iaw a1-h60ra-150-300 wp 026 00.  area fod free and secure.  '),
#  ('blue blade cuff bolts have minor surface corrosion. ccdd:19jul19',
#   'removed corrosion cleaned treated and preserved blue blade cuff bolts with primer iaw:01-1a-509. area secure and fod free at time of inspection'),
#  ('mrh low          ',
#   'serviced mrh iaw gai-000. serviced to second green,1500 psi, 26 degrees celcius at 2402.1 flight hours. area fod free and secure. utilized pema 8787.  '),
#  ('tail rotor  vibe ool.          ',
#   'performed tail adjustment of +53 grams in quad 2 and +109 grams in quad 3. area secure and fod free.  '),
#  ('main rotor head vibes ool          ',
#   'adjusted black pcr neg 1 click and blue trim tab pos 8 mils iaw imds ground station and vib-200. verified torques iaw 150-300. area clean and fod free.  '),
#  ('mrh accum low          ',
#   'serviced mrh iaw gai-000. fluid level mid high green, 1400 ps1, 27 c. checked area fod free and secure.  '),
#  ('blue pitch lock liner gouged          ',
#   'verifed gouge of pitch lock liner within limits iaw a1-h60ra-150-300. area checked fod free and secure.  '),
#  ('yellow damper outboard bearing ool.          ',
#   'removed and replaced yellow damper bearings iaw 150-300 ; refer to jcn:by0346274 for 9-13. area secured and fod free. pema 6fksa75955. area corrosion and fod free.  '),
#  ('black pitch lock will not retract.',
#   'removed and replaced black blade pitch lock actuator iaw 150-300 . system checks good iaw 150-200. area secure and corrosion / fod check complete. pema 46- 6fksa75951'),
#  ('perform ground vibes fcf# 02-17-002          ',
#   'performed post pmi/phase ground vibes analysis. all vibes checked good iaw vib 200 . fcf # 02-17-002.  '),
#  ('mrh low.          ',
#   'serviced mrh accumulator iaw gai-000. hyd: high green nit: 1600psi oat: 10c. area fod free and secure at time of inspection. refer to mcn: 16pl2yl for conditional inspection.  '),
#  ('blue blade upper centering socket loose          ',
#   'inspected blue blade upper centering socket iaw 150-300. no movement noted. area secure and fod free. pema: 6cksa67629  '),
#  ('ac-70.3 outboard retention plate pilot bushings measure 2.260. limit is no greater than 2.2515.          ',
#   'removed and replaced outboard retention plate iaw 150-300. refer to jcn: by0142053 for retq 9-13 outboard ret plate. area secure and fod free. pema s/n: 8fkka48559.  '),
#  ('scir change:  26xi514.  red and black spindle lower weight bracket have minor surface corrosion.          ',
#   'removed all corrosion from red and black spindle lower wieght bracket, cleaned, treated, and preserved iaw na 01-1a-509-2. used sem pen batch # 011518m. area secure and fod free at time of inspection.  '),
#  ('outboard retention plate found corroded and pitted.',
#   'removed and replaced outboard retention plate iaw 150-300. area secure and fod free. pema s/n: 6fksa76035. refer to jcn: by0198224 for 9-13 torque check.'),
#  ('tear in yellow trb          ',
#   'repaired tear in yellow trb iaw srm-000. area secure and fod free.  '),
#  ('maint rotor head servicing low          ',
#   'serviced main rotor head accumulator to yellow. iaw a1-h60ra-gai-000. nitrogen is at 1550 psi. oat is 25 c. aircraft hours now 577.7. area fod free and secure.  '),
#  ('rh nose tire requires replacment due to replacement of lh nose tire iaw navair 04-10-506          ',
#   'replaced rh nlg tire iaw sss3240 used pema04459. ataf. apaf.aff.  '),
#  ('evidence of leaking on yellow main rotor blade damper          ',
#   'inspected yellow damper iaw 150-300. leak is within 5 drop per minute limit. checks good. area fod free and secure.  '),
#  ('black damper outboard h/w 9-13 torque check failed.          ',
#   'torqued black damper outboard h/w iaw 150-300. refer to jcn:q70353568 for new 9-13 torque checks. area secure and fod free.  '),
#  ...]

# %%
f = open('Data/gpt3.txt', 'w')
subset = random.sample(pairs, 25)
for pair in subset:
    f.write('<DISCREPANCY> %s <ACTION> %s\n' % (pair[0].strip(), pair[1].strip()))
